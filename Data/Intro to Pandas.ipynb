# %%
import pandas as pd


url = "https://google.com/data"
df = pd.read_csv(url, header = None) #assumes first row is the header, if not, assign header as None and panda will automaticall assign numbers as header column.
print(df.head(5)) #shows first 5 rows of the data
print(df.tail(5)) #shows botom 5 rows f the data
headers = ["Symbol", "Manufacturer", "Year", "Doors", "Engine Size", "Number of Cylinders" "Price"
]
df.columns= headers
New_url=  df.to_csv(https://newfilepath/onlocalorinternet)
Read_files = pd.read_csv(), pd.read_json(), pd.read_excel(), pd.read_sql()
Save_files = pd.to_csv(), pd.to_json(), pd.to_excel(), pd.to_sql()

datatypes = df.dtypes
describe_summary_statistics = df.describe()
describe_summary_statistics_all = df.describe(include ="all") #Include all attributes including non integer/float data types
#NaN = Not a number

Info = df.info() #index, dtype, non-null values, memory usage.

#Accessing Databases with Python
# Connection Objects- Database connections,manage transactions
#Cursor Objects- Used to run database queries, used to scan through the results of a DB
#Connection_methods = cursor()- returns a new cursor object using the connection, commit()- commits any pending transaction to the DB, 
# rollback()-causes the DB to rollback to the start of any pending transaction, close()- to close a Database connection.

# %%
#Write code using DB-API

from dmodule import connect

#Create a connection object
connection = connect('databasename', 'username', 'pswd')

#Create a cursor object
cursor = connection.cursor()
#Run queries
cursor.execute('Select * FROM myTable LIMIT 10')
results = cursor.fetchall

#Free connections
connection.close()
cursor.close()
